# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     C:\Users\7200\AppData\Local\anaconda3
# tf                    *  C:\Users\7200\AppData\Local\anaconda3\envs\tf
# yolov5                   C:\Users\7200\AppData\Local\anaconda3\envs\yolov5

# %%
# !pip install pandas seaborn
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (2.2.3)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from pandas) (2025.2)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Downloading matplotlib-3.10.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading contourpy-1.3.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading fonttools-4.56.0-cp313-cp313-macosx_10_13_universal2.whl.metadata (101 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading kiwisolver-1.4.8-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.2 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Collecting pillow>=8 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pillow-11.1.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading matplotlib-3.10.1-cp313-cp313-macosx_11_0_arm64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 9.9 MB/s eta 0:00:00ta 0:00:01
# Downloading contourpy-1.3.1-cp313-cp313-macosx_11_0_arm64.whl (255 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.56.0-cp313-cp313-macosx_10_13_universal2.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 10.5 MB/s eta 0:00:00a 0:00:01
# Downloading kiwisolver-1.4.8-cp313-cp313-macosx_11_0_arm64.whl (65 kB)
# Downloading pillow-11.1.0-cp313-cp313-macosx_11_0_arm64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 9.8 MB/s eta 0:00:00ta 0:00:01
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.56.0 kiwisolver-1.4.8 matplotlib-3.10.1 pillow-11.1.0 pyparsing-3.2.3 seaborn-0.13.2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Perceptron Using Framework

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp313-cp313-macosx_12_0_arm64.whl.metadata (31 kB)
# Requirement already satisfied: numpy>=1.19.5 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from scikit-learn) (2.2.4)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.15.2-cp313-cp313-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp313-cp313-macosx_12_0_arm64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 10.0 MB/s eta 0:00:00a 0:00:01
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading scipy-1.15.2-cp313-cp313-macosx_14_0_arm64.whl (22.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 11.2 MB/s eta 0:00:00a 0:00:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 scipy-1.15.2 threadpoolctl-3.6.0

# %%
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples=100, n_features=2, n_redundant=0, n_informative=2, n_clusters_per_class=1)

# %%
X.shape
# Out:
# (100, 2)

# %% [markdown]
# ## Plot the dataset

# %%
plt.plot(X[y==0][:,0], X[y==0][:,1], "o", label="NOT PLACED", color="red")
plt.plot(X[y==1][:,0], X[y==1][:,1], "o", label="PLACED", color="green")
plt.legend()
plt.xlabel("CGPA")
plt.ylabel("Resume Score")
# Out:
# Text(0, 0.5, 'Resume Score')

# %% [markdown]
# ## Train Perceptron

# %%
from sklearn.linear_model import Perceptron

# %%
p = Perceptron()
p.fit(X, y)
# Out:
# Perceptron()

# %% [markdown]
# ## Plot Decision Boundary

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from mlxtend) (1.15.2)
# Requirement already satisfied: numpy>=1.16.2 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from mlxtend) (2.2.4)
# Requirement already satisfied: pandas>=0.24.2 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from mlxtend) (3.10.1)
# Requirement already satisfied: joblib>=0.13.2 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from matplotlib>=3.0.0->mlxtend) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from matplotlib>=3.0.0->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/yolo/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 10.6 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X, y, clf=p, legend=2)
# Out:
# <Axes: >

# %% [markdown]
# # Perceptron Trick

# %%
def step(x):
  return 1 if x >= 0 else 0

# %%
def plot_perceptron_learning(X, y, weights):
    plt.plot(X[y==0][:,1], X[y==0][:,2], "o", label="NOT PLACED", color="red")
    plt.plot(X[y==1][:,1], X[y==1][:,2], "o", label="PLACED", color="green")

    if (weights[2] != 0):
        m = -weights[1] / weights[2]
        c = -weights[0] / weights[2]

        # Generate points for decision boundary
        x_values = np.linspace(X[:,1].min(), X[:,1].max(), 100)
    
        y = m * x_values + c

        # Plot decision boundary
        plt.plot(x_values, y, label="Decision Boundary", color="blue")

    plt.legend()
    plt.xlabel("CGPA")
    plt.ylabel("Resume Score")
    plt.title("Perceptron Learning Decision Boundary")
    plt.grid(True)
    plt.show()

# %%
def train_perceptron(X, y, epochs=1000, lr=0.01):
  X = np.insert(X, 0, 1, axis=1) # Add column  for dummy 1s (for bias multiplication)
  weights = np.zeros(X.shape[1])  # Initialize weights randomly

  for i in range(epochs):
    j = np.random.randint(0, X.shape[0]) # Randomly select a row
    z = np.dot(X[j], weights)
    y_pred = step(z)
    weights = weights + lr * (y[j] - y_pred) * X[j]

  plot_perceptron_learning(X, y, weights)
  intercept_, coef_ = weights[0], weights[1:]
  return intercept_, coef_

# %%
intercept_, coef_ = train_perceptron(X, y)
print("Perceptron trained successfully")
print(f"intercept x0: {intercept_}")
print(f"coef w1, w2: {coef_}")
# Out:
# Perceptron trained successfully
# intercept x0: -0.05
# coef w1, w2: [-0.03257717 -0.05347865]

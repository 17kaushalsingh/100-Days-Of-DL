# %% [markdown]
# ## Import data and preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("diabetes.csv")

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X, X_test, y, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Hyperparameter tuning

# %%
import keras_tuner as kt

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout

# %%
def build_model(hp):

    model = Sequential()

    ## variable number of hidden layers
    num_layers = hp.Int('num_layers', min_value=1, max_value=10)

    for i in range(num_layers):
        num_units = hp.Choice(f'num_units_{i}', values=[8, 16, 32, 64, 128])
        activations = hp.Choice(f'activation_{i}', values=['relu', 'tanh', 'sigmoid', 'linear'])

        if i == 1: # first hidden layer
            model.add(Dense(units=num_units, activation=activations, input_dim=8))

        else: # other hidden layer
            model.add(Dense(units=num_units, activation=activations))
        
    ## output layer
    model.add(Dense(units=1, activation='sigmoid'))

    ## Compile the model
    optimizers = hp.Choice('optimizer', values=['adadelta', 'adagrad', 'adam', 'adamax', 'ftrl', 'nadam', 'rmsprop'])
    model.compile(loss='binary_crossentropy', optimizer=optimizers, metrics=['accuracy'])

    return model

# %%
tuner = kt.RandomSearch(build_model, objective='val_accuracy', max_trials=10,
                        directory='tune_all_params')

# %%
tuner.search(X, y, epochs=5, validation_data=(X_test, y_test))
# Out:
# Trial 10 Complete [00h 00m 01s]
# val_accuracy: 0.3311688303947449
#
# Best val_accuracy So Far: 0.7272727489471436
# Total elapsed time: 00h 00m 24s

# %%
best_params = tuner.get_best_hyperparameters()[0].values

# %%
best_params
# Out:
# {'num_layers': 9,
#  'num_units_0': 128,
#  'activation_0': 'tanh',
#  'optimizer': 'nadam',
#  'num_units_1': 128,
#  'activation_1': 'tanh',
#  'num_units_2': 16,
#  'activation_2': 'linear',
#  'num_units_3': 128,
#  'activation_3': 'relu',
#  'num_units_4': 32,
#  'activation_4': 'tanh',
#  'num_units_5': 128,
#  'activation_5': 'sigmoid',
#  'num_units_6': 32,
#  'activation_6': 'sigmoid',
#  'num_units_7': 32,
#  'activation_7': 'relu',
#  'num_units_8': 8,
#  'activation_8': 'relu'}

# %% [markdown]
# ## Train the best model

# %%
model = Sequential()

## Hidden layers
model.add(Dense(units=128, activation='tanh', input_dim=8))
model.add(Dense(units=128, activation='tanh'))
model.add(Dense(units=16, activation='linear'))
model.add(Dense(units=128, activation='relu'))
model.add(Dense(units=32, activation='tanh'))
model.add(Dense(units=128, activation='sigmoid'))
model.add(Dense(units=32, activation='sigmoid'))
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=8, activation='relu'))

## Output layers
model.add(Dense(units=1, activation='sigmoid'))

## Compile model
model.compile(loss='binary_crossentropy', optimizer='nadam', metrics=['accuracy'])

model.name = 'tuned_model'
model.summary()
# Out:
# Model: "tuned_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_23 (Dense)                │ (None, 128)            │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 16)             │         2,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 128)            │         2,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 128)            │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 8)              │           264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 35,713 (139.50 KB)
#  Trainable params: 35,713 (139.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X, y, epochs=100, validation_data=(X_test, y_test))
history = history.history
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.3458 - loss: 1.0203 - val_accuracy: 0.6623 - val_loss: 0.6807
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9421 - loss: 0.1927 - val_accuracy: 0.6753 - val_loss: 0.8923
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9116 - loss: 0.2250 - val_accuracy: 0.7727 - val_loss: 0.8162
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9331 - loss: 0.1898 - val_accuracy: 0.7208 - val_loss: 0.8017
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9262 - loss: 0.2179 - val_accuracy: 0.7403 - val_loss: 0.8142
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9586 - loss: 0.1273 - val_accuracy: 0.7273 - val_loss: 0.7794
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9595 - loss: 0.1490 - val_accuracy: 0.7208 - val_loss: 0.8194
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9703 - loss: 0.1257 - val_accuracy: 0.7403 - val_loss: 0.8163
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9736 - loss: 0.1175 - val_accuracy: 0.7208 - val_loss: 0.8543
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9687 - loss: 0.1310 - val_accuracy: 0.7273 - val_loss: 0.8184
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9696 - loss: 0.1290 - val_accuracy: 0.7597 - val_loss: 0.7968
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9719 - loss: 0.1256 - val_accuracy: 0.7597 - val_loss: 0.8181
# Epoch 83/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9691 - loss: 0.1187 - val_accuracy: 0.7273 - val_loss: 0.8588
# Epoch 84/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9627 - loss: 0.1189 - val_accuracy: 0.7078 - val_loss: 0.8798
# Epoch 85/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9639 - loss: 0.1260 - val_accuracy: 0.7468 - val_loss: 0.8610
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9772 - loss: 0.0943 - val_accuracy: 0.7532 - val_loss: 0.8973
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9788 - loss: 0.0752 - val_accuracy: 0.7143 - val_loss: 0.9501
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9722 - loss: 0.1107 - val_accuracy: 0.7143 - val_loss: 0.9499
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9801 - loss: 0.0854 - val_accuracy: 0.7273 - val_loss: 0.9539
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9793 - loss: 0.0805 - val_accuracy: 0.7208 - val_loss: 0.9456
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9822 - loss: 0.0800 - val_accuracy: 0.7403 - val_loss: 0.9427
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9840 - loss: 0.0655 - val_accuracy: 0.7208 - val_loss: 0.9618
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9795 - loss: 0.0818 - val_accuracy: 0.7273 - val_loss: 0.9705
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9815 - loss: 0.0733 - val_accuracy: 0.7143 - val_loss: 1.0008
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9785 - loss: 0.0835 - val_accuracy: 0.7338 - val_loss: 1.0002
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9807 - loss: 0.0736 - val_accuracy: 0.7273 - val_loss: 0.9961
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9746 - loss: 0.0831 - val_accuracy: 0.7078 - val_loss: 1.0490
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9783 - loss: 0.0792 - val_accuracy: 0.7403 - val_loss: 1.0405
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9786 - loss: 0.0708 - val_accuracy: 0.7338 - val_loss: 1.0635
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9818 - loss: 0.0648 - val_accuracy: 0.7273 - val_loss: 1.0870

# %%
plt.plot(history['loss'], label='train loss', color='blue')
plt.plot(history['val_loss'], label='val loss', color='green')
plt.title('Loss')
plt.legend()
plt.show()
plt.savefig('loss.png')

plt.plot(history['accuracy'], label='train accuracy', color='blue')
plt.plot(history['val_accuracy'], label='val accuracy', color='green')
plt.legend()
plt.title('Accuracy')
plt.show()
plt.savefig('accuracy.png')

# %%
y_pred = model.predict(X_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
y_pred = np.where(y_pred >= 0.5, 1, 0)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.7272727272727273

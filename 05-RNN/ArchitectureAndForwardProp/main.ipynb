# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense, SimpleRNN
from keras.utils import plot_model

# %%
model = Sequential()

model.add(SimpleRNN(units=3, input_shape=(4, 5)))

model.add(Dense(units=1, activation='sigmoid'))
# Out:
# c:\Users\7200\AppData\Local\anaconda3\envs\tf\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.name = 'simple_rnn'
model.summary()
# Out:
# Model: "simple_rnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 3)              │            27 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31 (124.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
for layer in model.layers:
    print(f"layer name: {layer.name}")
    print ("xx"*30)
    for weights in layer.get_weights():
        print("+"*10)
        print()
        print(weights)
# Out:
# layer name: simple_rnn
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ++++++++++
#
# [[ 0.23427194  0.24784225 -0.64727443]
#  [ 0.69698733 -0.5626769  -0.7306007 ]
#  [-0.44765827 -0.8558261  -0.84162027]
#  [-0.6865814   0.67647    -0.7214947 ]
#  [ 0.36427146  0.35165185  0.17231709]]
# ++++++++++
#
# [[-0.13867009  0.22442748  0.9645739 ]
#  [ 0.05028726  0.9743233  -0.21946639]
#  [-0.989061    0.01807234 -0.14639544]]
# ++++++++++
#
# [0. 0. 0.]
# layer name: dense
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ++++++++++
#
# [[0.29098845]
#  [0.0091362 ]
#  [0.37840652]]
# ++++++++++
#
# [0.]

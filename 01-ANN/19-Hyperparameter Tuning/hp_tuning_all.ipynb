# %% [markdown]
# ## Import data and preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("diabetes.csv")

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X, X_test, y, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Hyperparameter tuning

# %%
import keras_tuner as kt

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout

# %%
def build_model(hp):

    model = Sequential()

    ## variable number of hidden layers
    num_layers = hp.Int('num_layers', min_value=1, max_value=10)

    for i in range(num_layers):
        num_units = hp.Choice(f'num_units_{i}', values=[8, 16, 32, 64, 128])
        activations = hp.Choice(f'activation_{i}', values=['relu', 'tanh', 'sigmoid', 'linear'])

        if i == 0: # first hidden layer
            model.add(Dense(units=num_units, activation=activations, input_dim=8))

        else: # other hidden layer
            model.add(Dense(units=num_units, activation=activations))
        
    ## output layer
    model.add(Dense(units=1, activation='sigmoid'))

    ## Compile the model
    optimizers = hp.Choice('optimizer', values=['adadelta', 'adagrad', 'adam', 'adamax', 'ftrl', 'nadam', 'rmsprop'])
    model.compile(loss='binary_crossentropy', optimizer=optimizers, metrics=['accuracy'])

    return model

# %%
tuner = kt.RandomSearch(build_model, objective='val_accuracy', max_trials=10,
                        directory='tune_all_params')
# Out:
# Reloading Tuner from tune_all_params\untitled_project\tuner0.json

# %%
tuner.search(X, y, epochs=5, validation_data=(X_test, y_test))

# %%
best_params = tuner.get_best_hyperparameters()[0].values
best_params
# Out:
# {'num_layers': 9,
#  'num_units_0': 128,
#  'activation_0': 'tanh',
#  'optimizer': 'nadam',
#  'num_units_1': 128,
#  'activation_1': 'tanh',
#  'num_units_2': 16,
#  'activation_2': 'linear',
#  'num_units_3': 128,
#  'activation_3': 'relu',
#  'num_units_4': 32,
#  'activation_4': 'tanh',
#  'num_units_5': 128,
#  'activation_5': 'sigmoid',
#  'num_units_6': 32,
#  'activation_6': 'sigmoid',
#  'num_units_7': 32,
#  'activation_7': 'relu',
#  'num_units_8': 8,
#  'activation_8': 'relu'}

# %% [markdown]
# ## Train the best model

# %%
model = Sequential()

## Hidden layers
model.add(Dense(units=128, activation='tanh', input_dim=8))
model.add(Dense(units=128, activation='tanh'))
model.add(Dense(units=16, activation='linear'))
model.add(Dense(units=128, activation='relu'))
model.add(Dense(units=32, activation='tanh'))
model.add(Dense(units=128, activation='sigmoid'))
model.add(Dense(units=32, activation='sigmoid'))
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=8, activation='relu'))

## Output layers
model.add(Dense(units=1, activation='sigmoid'))

## Compile model
model.compile(loss='binary_crossentropy', optimizer='nadam', metrics=['accuracy'])

model.name = 'tuned_model'
model.summary()
# Out:
# c:\Users\7200\AppData\Local\anaconda3\envs\tf\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "tuned_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │         2,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │         2,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 8)              │           264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 35,713 (139.50 KB)
#  Trainable params: 35,713 (139.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X, y, epochs=100, validation_data=(X_test, y_test))
history = history.history
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.4415 - loss: 0.7147 - val_accuracy: 0.6039 - val_loss: 0.6457
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6527 - loss: 0.6034 - val_accuracy: 0.7338 - val_loss: 0.5817
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9857 - loss: 0.0583 - val_accuracy: 0.7338 - val_loss: 1.1066
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9824 - loss: 0.0647 - val_accuracy: 0.7208 - val_loss: 1.1553
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9765 - loss: 0.0726 - val_accuracy: 0.7208 - val_loss: 1.1471
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9775 - loss: 0.0687 - val_accuracy: 0.7468 - val_loss: 1.1502
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9750 - loss: 0.1008 - val_accuracy: 0.7468 - val_loss: 1.0001
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9752 - loss: 0.0909 - val_accuracy: 0.7078 - val_loss: 1.1290
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9420 - loss: 0.1676 - val_accuracy: 0.7208 - val_loss: 0.9067
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9360 - loss: 0.1834 - val_accuracy: 0.7403 - val_loss: 0.9222
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9418 - loss: 0.1979 - val_accuracy: 0.7143 - val_loss: 0.8173
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9475 - loss: 0.1798 - val_accuracy: 0.6818 - val_loss: 0.9079
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9472 - loss: 0.1515 - val_accuracy: 0.7532 - val_loss: 0.8436
# Epoch 83/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9274 - loss: 0.1746 - val_accuracy: 0.7468 - val_loss: 0.8457
# Epoch 84/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9672 - loss: 0.1003 - val_accuracy: 0.7597 - val_loss: 0.8171
# Epoch 85/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9569 - loss: 0.1083 - val_accuracy: 0.7273 - val_loss: 0.9156
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9815 - loss: 0.0835 - val_accuracy: 0.7468 - val_loss: 0.9439
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9694 - loss: 0.1103 - val_accuracy: 0.7468 - val_loss: 0.9392
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9731 - loss: 0.0799 - val_accuracy: 0.7403 - val_loss: 1.0239
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9884 - loss: 0.0440 - val_accuracy: 0.7597 - val_loss: 0.9371
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9812 - loss: 0.0596 - val_accuracy: 0.7468 - val_loss: 0.9994
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9869 - loss: 0.0446 - val_accuracy: 0.7468 - val_loss: 1.0198
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9888 - loss: 0.0475 - val_accuracy: 0.7468 - val_loss: 1.0091
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9864 - loss: 0.0341 - val_accuracy: 0.7532 - val_loss: 1.0751
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9884 - loss: 0.0339 - val_accuracy: 0.7532 - val_loss: 1.0421
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9847 - loss: 0.0392 - val_accuracy: 0.7532 - val_loss: 1.0726
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9835 - loss: 0.0413 - val_accuracy: 0.7532 - val_loss: 1.0649
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9874 - loss: 0.0304 - val_accuracy: 0.7532 - val_loss: 1.0832
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9838 - loss: 0.0336 - val_accuracy: 0.7597 - val_loss: 1.0760
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9890 - loss: 0.0285 - val_accuracy: 0.7597 - val_loss: 1.0765
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9857 - loss: 0.0305 - val_accuracy: 0.7532 - val_loss: 1.1190

# %%
plt.plot(history['loss'], label='train loss', color='blue')
plt.plot(history['val_loss'], label='val loss', color='green')
plt.title('Loss')
plt.legend()
plt.show()
plt.savefig('loss.png')

plt.plot(history['accuracy'], label='train accuracy', color='blue')
plt.plot(history['val_accuracy'], label='val accuracy', color='green')
plt.legend()
plt.title('Accuracy')
plt.show()
plt.savefig('accuracy.png')

# %%
y_pred = model.predict(X_test)
y_pred = np.where(y_pred >= 0.5, 1, 0)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.7532467532467533

# %% [markdown]
# `Cat:` 0 and `Dog:` 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.regularizers import l2

# %% [markdown]
# # Train Model

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !kaggle datasets download -d salader/dogs-vs-cats

import zipfile
zip_ref = zipfile.ZipFile('/content/dogs-vs-cats.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# !rm /content/dogs-vs-cats.zip
# !rm -rf /content/dogs_vs_cats
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/salader/dogs-vs-cats
# License(s): unknown

# %%
import os
path_to_dataset = input("Enter relative path to dataset: ")
print("Path to dataset: ", path_to_dataset)
test_path = os.path.join(path_to_dataset, 'test')
print("Path to test dataset: ", test_path)
train_path = os.path.join(path_to_dataset, 'train')
print("Path to train dataset: ", train_path)
# Out:
# Enter relative path to dataset: .
# Path to dataset:  .
# Path to test dataset:  ./test
# Path to train dataset:  ./train

# %%
train_data = tf.keras.utils.image_dataset_from_directory(
    directory=train_path,
    labels='inferred',
    label_mode='int',
    batch_size=32,
    image_size=(256, 256),
)

val_data = tf.keras.utils.image_dataset_from_directory(
    directory=test_path,
    labels='inferred',
    label_mode='int',
    batch_size=32,
    image_size=(256, 256),
)
# Out:
# Found 20000 files belonging to 2 classes.
# Found 5000 files belonging to 2 classes.

# %%
def preprocess(image, label):
    image = tf.cast(image/255.0, tf.float32)
    return image, label

# %%
train_data = train_data.map(preprocess)
val_data = val_data.map(preprocess)

# %%
model = Sequential()

## Convolutional layers
model.add(Conv2D(filters=32, kernel_size=(3, 3), strides=1, padding='valid', activation='relu', input_shape=(256, 256, 3), name='2d_conv_l1'))
model.add(BatchNormalization(name='batch_normalization_l1'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid', name='max_pooling_l1'))

model.add(Conv2D(filters=64, kernel_size=(3, 3), strides=1, padding='valid', activation='relu', name='2d_conv_l2'))
model.add(BatchNormalization(name='batch_normalization_l2'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid', name='max_pooling_l2'))

model.add(Conv2D(filters=128, kernel_size=(3, 3), strides=1, padding='valid', activation='relu', name='2d_conv_l3'))
model.add(BatchNormalization(name='batch_normalization_l3'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid', name='max_pooling_l3'))

## Flatten Layer
model.add(Flatten(name='flatten'))

## Fully connected layers
model.add(Dense(units=128, activation='relu', kernel_regularizer=l2, name='fully_connected_layer_1'))
model.add(BatchNormalization(name='batch_normalization_l4'))
model.add(Dropout(0.1, name='Dropout_l1'))

model.add(Dense(units=64, activation='relu', kernel_regularizer=l2, name='fully_connected_layer_2'))
model.add(BatchNormalization(name='batch_normalization_l5'))
model.add(Dropout(0.1, name='Dropout_l2'))

model.add(Dense(units=1, activation='sigmoid', kernel_regularizer=l2, name='fully_connected_layer_3'))

model.name = 'cat_dog_cls'

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "cat_dog_cls"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 2d_conv_l1 (Conv2D)             │ (None, 254, 254, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_l1          │ (None, 254, 254, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling_l1 (MaxPooling2D)   │ (None, 127, 127, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 2d_conv_l2 (Conv2D)             │ (None, 125, 125, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_l2          │ (None, 125, 125, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling_l2 (MaxPooling2D)   │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 2d_conv_l3 (Conv2D)             │ (None, 60, 60, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_l3          │ (None, 60, 60, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling_l3 (MaxPooling2D)   │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 115200)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fully_connected_layer_1 (Dense) │ (None, 128)            │    14,745,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_l4          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout_l1 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fully_connected_layer_2 (Dense) │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_l5          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout_l2 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fully_connected_layer_3 (Dense) │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,848,961 (56.64 MB)
#  Trainable params: 14,848,129 (56.64 MB)
#  Non-trainable params: 832 (3.25 KB)

# %%
history = model.fit(train_data, epochs=10, validation_data=val_data).history
model.save('/content/drive/MyDrive/cat_dog_cls.keras')
# Out:
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 81ms/step - accuracy: 0.6521 - loss: 3.1452 - val_accuracy: 0.6816 - val_loss: 1.5257
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 74s 85ms/step - accuracy: 0.7173 - loss: 1.2560 - val_accuracy: 0.7430 - val_loss: 1.1259
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 84ms/step - accuracy: 0.7665 - loss: 1.1300 - val_accuracy: 0.7604 - val_loss: 1.3461
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 84ms/step - accuracy: 0.7918 - loss: 1.2697 - val_accuracy: 0.7604 - val_loss: 1.4574
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 48s 77ms/step - accuracy: 0.8086 - loss: 1.5234 - val_accuracy: 0.7574 - val_loss: 1.7976
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 80ms/step - accuracy: 0.8242 - loss: 1.6626 - val_accuracy: 0.7888 - val_loss: 1.6468
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 77ms/step - accuracy: 0.8443 - loss: 1.6412 - val_accuracy: 0.7810 - val_loss: 1.8651
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 79ms/step - accuracy: 0.8582 - loss: 1.7181 - val_accuracy: 0.7954 - val_loss: 1.8168
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 86s 85ms/step - accuracy: 0.8677 - loss: 1.5642 - val_accuracy: 0.8024 - val_loss: 1.6116
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 79ms/step - accuracy: 0.8797 - loss: 1.4454 - val_accuracy: 0.8712 - val_loss: 1.4620

# %%
history = model.fit(train_data, epochs=50, validation_data=val_data, initial_epoch=10).history
model.save('/content/drive/MyDrive/cat_dog_cls.keras')
# Out:
# Epoch 11/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 54s 86ms/step - accuracy: 0.8917 - loss: 1.3640 - val_accuracy: 0.8382 - val_loss: 1.3297
# Epoch 12/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 48s 76ms/step - accuracy: 0.8946 - loss: 1.3085 - val_accuracy: 0.8212 - val_loss: 1.6968
# Epoch 13/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 83ms/step - accuracy: 0.9134 - loss: 1.2861 - val_accuracy: 0.8536 - val_loss: 1.3828
# Epoch 14/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 77ms/step - accuracy: 0.9089 - loss: 1.2269 - val_accuracy: 0.8724 - val_loss: 1.3582
# Epoch 15/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 79ms/step - accuracy: 0.9199 - loss: 1.1971 - val_accuracy: 0.8438 - val_loss: 1.4456
# Epoch 16/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 85s 84ms/step - accuracy: 0.9287 - loss: 1.1116 - val_accuracy: 0.8518 - val_loss: 1.1756
# Epoch 17/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 77ms/step - accuracy: 0.9288 - loss: 1.0219 - val_accuracy: 0.8598 - val_loss: 1.1201
# Epoch 18/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 84ms/step - accuracy: 0.9291 - loss: 0.9340 - val_accuracy: 0.8506 - val_loss: 1.2368
# Epoch 19/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 85ms/step - accuracy: 0.9314 - loss: 0.9087 - val_accuracy: 0.8864 - val_loss: 0.9572
# Epoch 20/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9381 - loss: 0.7995 - val_accuracy: 0.8626 - val_loss: 0.9402
# Epoch 21/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 86s 85ms/step - accuracy: 0.9365 - loss: 0.7709 - val_accuracy: 0.7922 - val_loss: 1.1529
# Epoch 22/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 84ms/step - accuracy: 0.9403 - loss: 0.6852 - val_accuracy: 0.8764 - val_loss: 0.8028
# Epoch 23/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 85ms/step - accuracy: 0.9428 - loss: 0.6643 - val_accuracy: 0.8450 - val_loss: 0.9557
# Epoch 24/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9482 - loss: 0.6680 - val_accuracy: 0.8760 - val_loss: 0.7047
# Epoch 25/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 86s 84ms/step - accuracy: 0.9494 - loss: 0.5772 - val_accuracy: 0.8746 - val_loss: 0.8459
# Epoch 26/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 80ms/step - accuracy: 0.9479 - loss: 0.5820 - val_accuracy: 0.8702 - val_loss: 0.8073
# Epoch 27/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 85s 84ms/step - accuracy: 0.9453 - loss: 0.5593 - val_accuracy: 0.8904 - val_loss: 0.6970
# Epoch 28/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 84ms/step - accuracy: 0.9498 - loss: 0.5417 - val_accuracy: 0.8978 - val_loss: 0.7490
# Epoch 29/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 79ms/step - accuracy: 0.9535 - loss: 0.5266 - val_accuracy: 0.8900 - val_loss: 0.6720
# Epoch 30/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 86s 85ms/step - accuracy: 0.9490 - loss: 0.5349 - val_accuracy: 0.8928 - val_loss: 0.7511
# Epoch 31/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 84ms/step - accuracy: 0.9567 - loss: 0.5475 - val_accuracy: 0.8644 - val_loss: 0.8038
# Epoch 32/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 50s 79ms/step - accuracy: 0.9481 - loss: 0.5623 - val_accuracy: 0.8706 - val_loss: 0.8710
# Epoch 33/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 84ms/step - accuracy: 0.9554 - loss: 0.5557 - val_accuracy: 0.8488 - val_loss: 0.9622
# Epoch 34/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 84ms/step - accuracy: 0.9558 - loss: 0.5307 - val_accuracy: 0.8740 - val_loss: 0.7850
# Epoch 35/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 48s 77ms/step - accuracy: 0.9535 - loss: 0.5024 - val_accuracy: 0.7690 - val_loss: 1.2073
# Epoch 36/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 84s 80ms/step - accuracy: 0.9539 - loss: 0.5210 - val_accuracy: 0.8864 - val_loss: 0.7418
# Epoch 37/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 77ms/step - accuracy: 0.9554 - loss: 0.5353 - val_accuracy: 0.8538 - val_loss: 0.8482
# Epoch 38/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 84ms/step - accuracy: 0.9606 - loss: 0.5340 - val_accuracy: 0.8328 - val_loss: 1.0791
# Epoch 39/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 84ms/step - accuracy: 0.9568 - loss: 0.5788 - val_accuracy: 0.8686 - val_loss: 0.8043
# Epoch 40/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 77ms/step - accuracy: 0.9607 - loss: 0.5226 - val_accuracy: 0.8958 - val_loss: 0.7230
# Epoch 41/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 86s 84ms/step - accuracy: 0.9565 - loss: 0.4965 - val_accuracy: 0.8510 - val_loss: 0.8628
# Epoch 42/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 84ms/step - accuracy: 0.9554 - loss: 0.4898 - val_accuracy: 0.8906 - val_loss: 0.6701
# Epoch 43/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 79ms/step - accuracy: 0.9584 - loss: 0.4719 - val_accuracy: 0.8722 - val_loss: 0.7225
# Epoch 44/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 86s 85ms/step - accuracy: 0.9626 - loss: 0.4532 - val_accuracy: 0.8954 - val_loss: 0.6617
# Epoch 45/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 79ms/step - accuracy: 0.9617 - loss: 0.4717 - val_accuracy: 0.8486 - val_loss: 0.8781
# Epoch 46/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 85s 85ms/step - accuracy: 0.9605 - loss: 0.4632 - val_accuracy: 0.8958 - val_loss: 0.6535
# Epoch 47/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 84ms/step - accuracy: 0.9638 - loss: 0.4418 - val_accuracy: 0.8688 - val_loss: 0.7841
# Epoch 48/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9630 - loss: 0.4676 - val_accuracy: 0.9020 - val_loss: 0.7197
# Epoch 49/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 80ms/step - accuracy: 0.9675 - loss: 0.4735 - val_accuracy: 0.8992 - val_loss: 0.6551
# Epoch 50/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9651 - loss: 0.4364 - val_accuracy: 0.8476 - val_loss: 0.8885

# %%
plt.plot(history['loss'], label='train loss', color='red')
plt.plot(history['val_loss'], label='val loss', color='green')
plt.title('Loss')
plt.legend()
plt.show()

plt.plot(history['accuracy'], label='train accuracy', color='red')
plt.plot(history['val_accuracy'], label='val accuracy', color='green')
plt.title('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # Load the trained model

# %%
trained_model = keras.models.load_model('cat_dog_cls.keras')
trained_model.summary()
# Out:
# Model: "cat_dog_cls"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 2d_conv_l1 (Conv2D)             │ (None, 254, 254, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_l1          │ (None, 254, 254, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling_l1 (MaxPooling2D)   │ (None, 127, 127, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 2d_conv_l2 (Conv2D)             │ (None, 125, 125, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_l2          │ (None, 125, 125, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling_l2 (MaxPooling2D)   │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 2d_conv_l3 (Conv2D)             │ (None, 60, 60, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_l3          │ (None, 60, 60, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling_l3 (MaxPooling2D)   │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 115200)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fully_connected_layer_1 (Dense) │ (None, 128)            │    14,745,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_l4          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout_l1 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fully_connected_layer_2 (Dense) │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_l5          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout_l2 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fully_connected_layer_3 (Dense) │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44,545,221 (169.93 MB)
#  Trainable params: 14,848,129 (56.64 MB)
#  Non-trainable params: 832 (3.25 KB)
#  Optimizer params: 29,696,260 (113.28 MB)

# %% [markdown]
# ## Test Model on Unseen Data
